# %% [markdown]
# # Python
# ## Operators

# %%
1 + 1
# Out:
# 2

# %%
2 * 3
# Out:
# 6

# %%
1==0

# %%
not (1==0)

# %%
(2==2) and (2==3)

# %%
(2==2) or (2==3)

# %% [markdown]
# ## Strings

# %%
'artificial' + "intelligence"

# %%
'artificial'.upper()

# %%
'HELP'.lower()

# %%
len('Help')

# %%
s = 'hello world'
print(s)

# %%
s.upper()

# %%
len(s.upper())

# %%
num = 8.0
num += 2.5
print(num)

# %%
s = 'abc'
dir(s)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(s.find)

# %%
s.find('b')
# Out:
# 1

# %% [markdown]
# ## Lists

# %%
fruits = ['apple','orange','pear','banana']
fruits[0]
# Out:
# 'apple'

# %%
otherFruits = ['kiwi','strawberry']
fruits + otherFruits
# Out:
# ['apple', 'orange', 'pear', 'banana', 'kiwi', 'strawberry']

# %% [markdown]
# Python also allows negative-indexing from the back of the list. For instance, fruits[-1] will
# access the last element 'banana':

# %%
fruits[-2]
# Out:
# 'pear'

# %%
fruits.pop()
# Out:
# 'orange'

# %%
fruits
# Out:
# ['apple', 'orange', 'pear']

# %%
fruits.append('grapefruit')
fruits
# Out:
# ['apple', 'orange', 'pear', 'grapefruit']

# %%
fruits[-1] = 'pineapple'
fruits
# Out:
# ['apple', 'orange', 'pear', 'pineapple']

# %% [markdown]
# We can also index multiple adjacent elements using the slice operator. For instance,
# fruits[1:3], returns a list containing the elements at position 1 and 2. In general
# fruits[start:stop] will get the elements in start, start+1, ..., stop-1. We can
# also do fruits[start:] which returns all elements starting from the start index. Also
# fruits[:end] will return all elements before the element at position end:

# %%
fruits[0:2]
# Out:
# ['apple', 'orange']

# %%
fruits[:3]
# Out:
# ['apple', 'orange', 'pear']

# %%
fruits[2:]
# Out:
# ['pear', 'pineapple']

# %%
len(fruits)
# Out:
# 4

# %% [markdown]
# The items stored in lists can be any Python data type. So for instance we can have lists of lists:

# %%
lstOfLsts = [['a','b','c'],[1,2,3],['one','two','three']]
lstOfLsts[1][2]
# Out:
# 3

# %%
lstOfLsts[0].pop()
# Out:
# 'c'

# %%
lstOfLsts
# Out:
# [['a', 'b'], [1, 2, 3], ['one', 'two', 'three']]

# %% [markdown]
# ## Exercise: Lists

# %% [markdown]
# Play with some of the list functions. You can find the methods you can call on an object via the
# dir and get information about them via the help command:

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
help(list.reverse)
# Out:
# Help on method_descriptor:
#
# reverse(self, /)
#     Reverse *IN PLACE*.

# %%
lst = ['a','b','c']
print(lst)
lst.reverse()
print(lst)
# Out:
# ['a', 'b', 'c']
# ['c', 'b', 'a']

# %% [markdown]
# Note: Ignore functions with underscores "_" around the names; these are private helper methods.
# Press 'q' to back out of a help screen.

# %% [markdown]
# ## Tuples

# %% [markdown]
# A data structure similar to the list is the tuple, which is like a list except that it is immutable once it
# is created (i.e. you cannot change its content once created). Note that tuples are surrounded with
# parentheses while lists have square brackets.

# %%
pair = (3,5)
pair[0]
# Out:
# 3

# %%
x,y = pair
x
# Out:
# 3

# %%
y
# Out:
# 5

# %%
pair[1] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-392fbb166e50> in <module>()
# ----> 1 pair[1] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# The attempt to modify an immutable structure raised an exception. Exceptions indicate errors:
# index out of bounds errors, type errors, and so on will all report exceptions in this way.

# %% [markdown]
# ## Sets

# %% [markdown]
# A set is another data structure that serves as an unordered list with no duplicate items. Below, we
# show how to create a set:

# %%
shapes = ['circle','square','triangle','circle']
setOfShapes = set(shapes)

# %% [markdown]
# Another way of creating a set is shown below:

# %%
setOfShapes = {'circle', 'square', 'triangle', 'circle'}

# %% [markdown]
# Next, we show how to add things to the set, test if an item is in the set, and perform common set
# operations (difference, intersection, union):

# %%
setOfShapes
# Out:
# {'circle', 'square', 'triangle'}

# %%
setOfShapes.add('polygon')
setOfShapes
# Out:
# {'circle', 'polygon', 'square', 'triangle'}

# %%
'circle' in setOfShapes
# Out:
# True

# %%
'rhombus' in setOfShapes
# Out:
# False

# %%
favoriteShapes = ['circle','triangle','hexagon']
setOfFavoriteShapes = set(favoriteShapes)
setOfShapes - setOfFavoriteShapes
# Out:
# {'polygon', 'square'}

# %%
setOfShapes & setOfFavoriteShapes
# Out:
# {'circle', 'triangle'}

# %%
setOfShapes | setOfFavoriteShapes
# Out:
# {'circle', 'hexagon', 'polygon', 'square', 'triangle'}

# %% [markdown]
# Note that the objects in the set are unordered; you cannot assume that their traversal or print
# order will be the same across machines!

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# The last built-in data structure is the dictionary which stores a map from one type of object (the
# key) to another (the value). The key must be an immutable type (string, number, or tuple). The
# value can be any Python data type.
# Note: In the example below, the printed order of the keys returned by Python could be different
# than shown below. The reason is that unlike lists which have a fixed ordering, a dictionary is simply
# a hash table for which there is no fixed ordering of the keys (like HashMaps in Java). The order of
# the keys depends on how exactly the hashing algorithm maps keys to buckets, and will usually
# seem arbitrary. Your code should not rely on key ordering, and you should not be surprised if evena small modification to how your code uses a dictionary results in a new key ordering.

# %%
studentIds = {'knuth': 42.0, 'turing': 56.0, 'nash': 92.0 }
studentIds['turing']
# Out:
# 56.0

# %%
studentIds['nash'] = 'ninety-two'
studentIds
# Out:
# {'knuth': 42.0, 'nash': 'ninety-two', 'turing': 56.0}

# %%
del studentIds['knuth']
studentIds
# Out:
# {'nash': 'ninety-two', 'turing': 56.0}

# %%
studentIds['knuth'] = [42.0,'forty-two']
studentIds
# Out:
# {'knuth': [42.0, 'forty-two'], 'nash': 'ninety-two', 'turing': 56.0}

# %%
studentIds.keys()
# Out:
# dict_keys(['turing', 'nash', 'knuth'])

# %%
studentIds.values()
# Out:
# dict_values([56.0, 'ninety-two', [42.0, 'forty-two']])

# %%
studentIds.items()
# Out:
# dict_items([('turing', 56.0), ('nash', 'ninety-two'), ('knuth', [42.0, 'forty-two'])])

# %%
len(studentIds)
# Out:
# 3

# %% [markdown]
# As with nested lists, you can also create dictionaries of dictionaries.

# %% [markdown]
# ## Exercise: Dictionaries

# %% [markdown]
# Use dir and help to learn about the functions you can call on dictionaries.

# %%
dir help
# Out:
#   File "<ipython-input-1-04495a8bdbe1>", line 1
#     dir help
#            ^
# SyntaxError: invalid syntax
